# %%
## all imports
from IPython.display import HTML
import numpy as np
#import urllib2 (Python2)
import urllib.request
import bs4 #this is beautiful soup
import time
import operator
import socket
#import cPickle (Python2)
import pickle
import re # regular expressions

from pandas import Series
import pandas as pd
from pandas import DataFrame

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set_context("talk")
sns.set_style("white")

# %% [markdown]
# # Scraping data science skills

# %% [markdown]
# - What skills are in demand for data scientists?
# - Should we have a lecture on Spark or only on MapReduce?
#
# We want to scrape the information from job advertisements for data scientists from indeed.com
# Let's scrape and find out!

# %% [markdown]
# ### Get website and parse html
# Using `BeautifulSoup` the html code of the Dutch version of indeed.com is parsed.

# %%
# Fixed url for job postings containing data scientist
url = 'https://www.indeed.nl/jobs?q=data+scientist&l='
# read the website
source = urllib.request.urlopen(url).read()
# parse html code
bs_tree = bs4.BeautifulSoup(source)

# %% [markdown]
# ### Job count
# Find the number of postings. Basically the search count is located on the 1st page of the website; use your browser's web developer tools to find the related tag and attributes. As this is a string we must cast it to an int taking into account possible thousands separators.<br><br>See also Remarks at the end of this notebook.

# %%
# August 2020 solution. Since 2015 Indeed.com altered the precise location of the total count of pages.
result_string = bs_tree.find('div', attrs = {"id": "searchCountPages"}).text
job_count_string = result_string.split(' ')[-2]
print ("Number of hits: ", job_count_string)
# statements below to handle thousands separator
job_count_digits = [int(d) for d in job_count_string if d.isdigit()]
job_count = np.sum([digit*(10**exponent) for digit, exponent in 
                    zip(job_count_digits[::-1], range(len(job_count_digits)))])
print (job_count)
# Out:
# Number of hits:  897
# 897

# %% [markdown]
# ### Job links
# The original CS109 2015 version assumes an exact amount of max 10 job postings per web page. At least on `indeed.nl` in August 2020 a variable number of job postings per page was encountered. So the number of pages calculation `num_pages = int(np.ceil(job_count/10))` is incorrect and cannot be used in the for loop. <br>
# The solution is to find all job postings per page (irrelevant if this is less or more than 10) in a while loop as long as the job_count is > 0. The job_count is decremented with number of jobs found on that page.<br><br>
# See also Remarks at the end of this notebook.

# %%
base_url = "https://www.indeed.nl"
job_links = []
i = 0
print (job_count)
while job_count > 0:
    job_postings = job_ids =[]
    # first page
    if i == 0:
        url = 'https://www.indeed.nl/jobs?q=data+scientist&l='
    else:
        url = 'https://www.indeed.nl/jobs?q=data+scientist&start=' + str(i * 10)
    html_page = urllib.request.urlopen(url).read()
    bs_tree = bs4.BeautifulSoup(html_page)
    job_link_area = bs_tree.find(id = 'resultsCol')
    # list with all divs of class "row result" in it
    job_postings = job_link_area.findAll("div", class_="jobsearch-SerpJobCard unifiedRow row result") 
    job_ids = [jp.get('data-jk') for jp in job_postings]
    # then for each job_link
    for id in job_ids:
        job_links.append(base_url + '/rc/clk?jk=' + id)
    time.sleep(1)
    job_count -= len(job_ids)
    print ("We found a lot of jobs: ", len(job_links), ". Remaining jobcount: ", job_count)
    i += 1
# Out:
# 897
# We found a lot of jobs:  15 . Remaining jobcount:  882
# We found a lot of jobs:  30 . Remaining jobcount:  867
# We found a lot of jobs:  45 . Remaining jobcount:  852
# We found a lot of jobs:  60 . Remaining jobcount:  837
# We found a lot of jobs:  75 . Remaining jobcount:  822
# We found a lot of jobs:  90 . Remaining jobcount:  807
# We found a lot of jobs:  105 . Remaining jobcount:  792
# We found a lot of jobs:  121 . Remaining jobcount:  776
# We found a lot of jobs:  136 . Remaining jobcount:  761
# We found a lot of jobs:  151 . Remaining jobcount:  746
# We found a lot of jobs:  166 . Remaining jobcount:  731
# We found a lot of jobs:  181 . Remaining jobcount:  716
# We found a lot of jobs:  196 . Remaining jobcount:  701
# We found a lot of jobs:  211 . Remaining jobcount:  686
# We found a lot of jobs:  226 . Remaining jobcount:  671
# We found a lot of jobs:  241 . Remaining jobcount:  656
# We found a lot of jobs:  256 . Remaining jobcount:  641
# We found a lot of jobs:  271 . Remaining jobcount:  626
# We found a lot of jobs:  286 . Remaining jobcount:  611
# We found a lot of jobs:  301 . Remaining jobcount:  596
# We found a lot of jobs:  316 . Remaining jobcount:  581
# We found a lot of jobs:  331 . Remaining jobcount:  566
# We found a lot of jobs:  346 . Remaining jobcount:  551
# We found a lot of jobs:  361 . Remaining jobcount:  536
# We found a lot of jobs:  376 . Remaining jobcount:  521
# We found a lot of jobs:  391 . Remaining jobcount:  506
# We found a lot of jobs:  406 . Remaining jobcount:  491
# We found a lot of jobs:  421 . Remaining jobcount:  476
# We found a lot of jobs:  436 . Remaining jobcount:  461
# We found a lot of jobs:  451 . Remaining jobcount:  446
# We found a lot of jobs:  466 . Remaining jobcount:  431
# We found a lot of jobs:  481 . Remaining jobcount:  416
# We found a lot of jobs:  496 . Remaining jobcount:  401
# We found a lot of jobs:  511 . Remaining jobcount:  386
# We found a lot of jobs:  526 . Remaining jobcount:  371
# We found a lot of jobs:  541 . Remaining jobcount:  356
# We found a lot of jobs:  556 . Remaining jobcount:  341
# We found a lot of jobs:  571 . Remaining jobcount:  326
# We found a lot of jobs:  586 . Remaining jobcount:  311
# We found a lot of jobs:  601 . Remaining jobcount:  296
# We found a lot of jobs:  616 . Remaining jobcount:  281
# We found a lot of jobs:  631 . Remaining jobcount:  266
# We found a lot of jobs:  646 . Remaining jobcount:  251
# We found a lot of jobs:  661 . Remaining jobcount:  236
# We found a lot of jobs:  677 . Remaining jobcount:  220
# We found a lot of jobs:  692 . Remaining jobcount:  205
# We found a lot of jobs:  707 . Remaining jobcount:  190
# We found a lot of jobs:  722 . Remaining jobcount:  175
# We found a lot of jobs:  737 . Remaining jobcount:  160
# We found a lot of jobs:  752 . Remaining jobcount:  145
# We found a lot of jobs:  768 . Remaining jobcount:  129
# We found a lot of jobs:  783 . Remaining jobcount:  114
# We found a lot of jobs:  799 . Remaining jobcount:  98
# We found a lot of jobs:  814 . Remaining jobcount:  83
# We found a lot of jobs:  829 . Remaining jobcount:  68
# We found a lot of jobs:  844 . Remaining jobcount:  53
# We found a lot of jobs:  853 . Remaining jobcount:  44
# We found a lot of jobs:  868 . Remaining jobcount:  29
# We found a lot of jobs:  883 . Remaining jobcount:  14
# We found a lot of jobs:  899 . Remaining jobcount:  -2

# %% [markdown]
# ### Some precautions to enable us to restart our search
# Write job_links to a file so it may be retrieved if needed.

# %%
# Save the scraped links
with open('data/scraped_links.pkl', 'wb') as f:
    pickle.dump(job_links, f)
    
# Read canned scraped links. 2nd arg should be `rb` read-binary
with open('data/scraped_links.pkl', 'rb') as f:
    job_links = pickle.load(f)

# %% [markdown]
# ### Skill set
# The desired skills to count in our job_link pages is stored in dictionary with value 0 as initialized count.

# %%
skill_set = {'mapreduce': 0, 'spark': 0, 'python': 0, 'r': 0, 'sql': 0, 'nosql': 0, 'sas': 0} 
# R is troublesome => in RE use raw string for \b which matches empty string before begin or after end of R

## write initialization into a file, so we can restart later
with open('data/scraped_links_restart.pkl', 'wb') as f:
    pickle.dump((skill_set, 0),f)
## read dictionary and index    
#with open('data/scraped_links_restart.pkl', 'rb') as f:
#    skill_set, index = pickle.load(f)

# %% [markdown]
# ### Check progress
# Code might be run to see the number of web_links yet to go. Code comment: CS109 2015

# %%
# This code below does the trick, but could be optimized for speed if necessary
# e.g. skills are typically listed at the end of the webpage
# might not need to split/join the whole webpage, as we already know
# which words we are looking for 
# and could stop after the first occurance of each word

with open('data/scraped_links_restart.pkl', 'rb') as f:
    skill_set, index = pickle.load(f)
    print ("How many websites still to go? ", len(job_links) - index)
# Out:
# How many websites still to go?  899

# %% [markdown]
# ### Count skills
# Count skills in skill_set dictionary. That is take the key (a string) and increment the value by 1 on first occurrence of key. Before we do so, the html text is cleaned using a regular expression.

# %%
counter = 0

for link in job_links[index:]:
    counter +=1  
    
    try:
        html_page = urllib.request.urlopen(link).read()
    except urllib.request.HTTPError:
        print ("HTTPError:")
        continue
    except urllib.request.URLError:
        print ("URLError:")
        continue
    except socket.error as error:
        print ("Connection closed")
        continue
    except:
        continue

    html_text = re.sub("[^a-z.+3]"," ", html_page.lower().decode('utf-8', errors="replace")) # replace all but the listed characters
    
    for key in skill_set.keys():
        if ' '+key+' ' in html_text: 
            skill_set[key] +=1
            
    if counter % 5 == 0:
        print (len(job_links) - counter - index)
        print (skill_set)
        with open('data/scraped_links_restart.pkl','wb') as f:
            pickle.dump((skill_set, index+counter),f)
# Out:
# 894
# {'mapreduce': 0, 'spark': 0, 'python': 4, 'r': 4, 'sql': 1, 'nosql': 0, 'sas': 0}
# HTTPError:
# 889
# {'mapreduce': 0, 'spark': 0, 'python': 8, 'r': 8, 'sql': 4, 'nosql': 1, 'sas': 0}
# HTTPError:
# HTTPError:
# HTTPError:
# 879
# {'mapreduce': 0, 'spark': 0, 'python': 13, 'r': 15, 'sql': 7, 'nosql': 1, 'sas': 0}
# HTTPError:
# HTTPError:
# HTTPError:
# HTTPError:
# HTTPError:
# URLError:
# 859
# {'mapreduce': 0, 'spark': 4, 'python': 23, 'r': 29, 'sql': 11, 'nosql': 1, 'sas': 1}
# HTTPError:
# HTTPError:
# 854
# {'mapreduce': 0, 'spark': 5, 'python': 26, 'r': 31, 'sql': 12, 'nosql': 1, 'sas': 2}
# 849
# {'mapreduce': 0, 'spark': 5, 'python': 29, 'r': 35, 'sql': 14, 'nosql': 2, 'sas': 3}
# HTTPError:
# HTTPError:
# 844
# {'mapreduce': 0, 'spark': 6, 'python': 32, 'r': 38, 'sql': 15, 'nosql': 3, 'sas': 3}
# 839
# {'mapreduce': 0, 'spark': 7, 'python': 36, 'r': 43, 'sql': 16, 'nosql': 4, 'sas': 3}
# 834
# {'mapreduce': 0, 'spark': 7, 'python': 38, 'r': 48, 'sql': 18, 'nosql': 4, 'sas': 3}
# HTTPError:
# 829
# {'mapreduce': 0, 'spark': 7, 'python': 40, 'r': 52, 'sql': 19, 'nosql': 4, 'sas': 3}
# HTTPError:
# HTTPError:
# 819
# {'mapreduce': 0, 'spark': 8, 'python': 42, 'r': 58, 'sql': 20, 'nosql': 4, 'sas': 4}
# HTTPError:
# 814
# {'mapreduce': 0, 'spark': 8, 'python': 44, 'r': 61, 'sql': 22, 'nosql': 4, 'sas': 4}
# HTTPError:
# 809
# {'mapreduce': 0, 'spark': 9, 'python': 47, 'r': 65, 'sql': 24, 'nosql': 4, 'sas': 5}
# 804
# {'mapreduce': 0, 'spark': 10, 'python': 51, 'r': 69, 'sql': 25, 'nosql': 4, 'sas': 5}
# HTTPError:
# 799
# {'mapreduce': 0, 'spark': 11, 'python': 54, 'r': 73, 'sql': 27, 'nosql': 6, 'sas': 5}
# HTTPError:
# 794
# {'mapreduce': 0, 'spark': 13, 'python': 56, 'r': 76, 'sql': 29, 'nosql': 7, 'sas': 6}
# 789
# {'mapreduce': 0, 'spark': 14, 'python': 57, 'r': 81, 'sql': 31, 'nosql': 7, 'sas': 8}
# HTTPError:
# 779
# {'mapreduce': 0, 'spark': 15, 'python': 63, 'r': 89, 'sql': 37, 'nosql': 7, 'sas': 8}
# URLError:
# 774
# {'mapreduce': 0, 'spark': 17, 'python': 66, 'r': 92, 'sql': 39, 'nosql': 7, 'sas': 8}
# HTTPError:
# HTTPError:
# 764
# {'mapreduce': 0, 'spark': 18, 'python': 72, 'r': 99, 'sql': 44, 'nosql': 8, 'sas': 8}
# HTTPError:
# HTTPError:
# 759
# {'mapreduce': 0, 'spark': 18, 'python': 73, 'r': 102, 'sql': 44, 'nosql': 8, 'sas': 8}
# HTTPError:
# HTTPError:
# 754
# {'mapreduce': 0, 'spark': 20, 'python': 75, 'r': 105, 'sql': 45, 'nosql': 9, 'sas': 8}
# HTTPError:
# HTTPError:
# 749
# {'mapreduce': 0, 'spark': 20, 'python': 78, 'r': 108, 'sql': 46, 'nosql': 10, 'sas': 8}
# HTTPError:
# HTTPError:
# HTTPError:
# HTTPError:
# HTTPError:
# 734
# {'mapreduce': 0, 'spark': 24, 'python': 84, 'r': 117, 'sql': 50, 'nosql': 12, 'sas': 9}
# HTTPError:
# 729
# {'mapreduce': 0, 'spark': 25, 'python': 86, 'r': 120, 'sql': 51, 'nosql': 12, 'sas': 9}
# URLError:
# HTTPError:
# HTTPError:
# 724
# {'mapreduce': 0, 'spark': 26, 'python': 87, 'r': 121, 'sql': 52, 'nosql': 13, 'sas': 9}
# HTTPError:
# 719
# {'mapreduce': 0, 'spark': 27, 'python': 90, 'r': 124, 'sql': 53, 'nosql': 13, 'sas': 9}
# HTTPError:
# 714
# {'mapreduce': 0, 'spark': 28, 'python': 92, 'r': 128, 'sql': 54, 'nosql': 14, 'sas': 9}
# HTTPError:
# 709
# {'mapreduce': 1, 'spark': 28, 'python': 94, 'r': 131, 'sql': 54, 'nosql': 15, 'sas': 9}
# 704
# {'mapreduce': 1, 'spark': 28, 'python': 96, 'r': 136, 'sql': 55, 'nosql': 15, 'sas': 9}
# 699
# {'mapreduce': 1, 'spark': 29, 'python': 98, 'r': 139, 'sql': 56, 'nosql': 15, 'sas': 9}
# URLError:
# HTTPError:
# 694
# {'mapreduce': 1, 'spark': 29, 'python': 99, 'r': 142, 'sql': 57, 'nosql': 16, 'sas': 10}
# URLError:
# HTTPError:
# 689
# {'mapreduce': 1, 'spark': 31, 'python': 101, 'r': 144, 'sql': 58, 'nosql': 16, 'sas': 10}
# URLError:
# 684
# {'mapreduce': 1, 'spark': 31, 'python': 103, 'r': 148, 'sql': 60, 'nosql': 16, 'sas': 11}
# HTTPError:
# 674
# {'mapreduce': 1, 'spark': 31, 'python': 107, 'r': 155, 'sql': 62, 'nosql': 17, 'sas': 11}
# 669
# {'mapreduce': 1, 'spark': 33, 'python': 111, 'r': 156, 'sql': 64, 'nosql': 17, 'sas': 11}
# URLError:
# HTTPError:
# 659
# {'mapreduce': 1, 'spark': 35, 'python': 114, 'r': 163, 'sql': 64, 'nosql': 17, 'sas': 11}
# URLError:
# 654
# {'mapreduce': 1, 'spark': 36, 'python': 115, 'r': 166, 'sql': 66, 'nosql': 17, 'sas': 12}
# URLError:
# HTTPError:
# HTTPError:
# 644
# {'mapreduce': 1, 'spark': 38, 'python': 120, 'r': 172, 'sql': 69, 'nosql': 18, 'sas': 12}
# 639
# {'mapreduce': 1, 'spark': 40, 'python': 122, 'r': 177, 'sql': 70, 'nosql': 18, 'sas': 12}
# URLError:
# HTTPError:
# 634
# {'mapreduce': 1, 'spark': 42, 'python': 124, 'r': 180, 'sql': 72, 'nosql': 18, 'sas': 12}
# HTTPError:
# URLError:
# 629
# {'mapreduce': 1, 'spark': 43, 'python': 126, 'r': 183, 'sql': 73, 'nosql': 18, 'sas': 12}
# 624
# {'mapreduce': 1, 'spark': 44, 'python': 129, 'r': 186, 'sql': 73, 'nosql': 18, 'sas': 12}
# HTTPError:
# 619
# {'mapreduce': 1, 'spark': 44, 'python': 131, 'r': 187, 'sql': 74, 'nosql': 18, 'sas': 12}
# URLError:
# URLError:
# 614
# {'mapreduce': 1, 'spark': 44, 'python': 133, 'r': 188, 'sql': 76, 'nosql': 18, 'sas': 12}
# URLError:
# 609
# {'mapreduce': 1, 'spark': 44, 'python': 133, 'r': 191, 'sql': 77, 'nosql': 18, 'sas': 12}
# URLError:
# HTTPError:
# URLError:
# URLError:
# URLError:
# 594
# {'mapreduce': 1, 'spark': 47, 'python': 135, 'r': 199, 'sql': 78, 'nosql': 18, 'sas': 14}
# HTTPError:
# HTTPError:
# 589
# {'mapreduce': 1, 'spark': 48, 'python': 137, 'r': 202, 'sql': 79, 'nosql': 18, 'sas': 15}
# 584
# {'mapreduce': 1, 'spark': 50, 'python': 140, 'r': 207, 'sql': 81, 'nosql': 20, 'sas': 15}
# HTTPError:
# HTTPError:
# URLError:
# URLError:
# HTTPError:
# 574
# {'mapreduce': 1, 'spark': 51, 'python': 143, 'r': 211, 'sql': 83, 'nosql': 21, 'sas': 15}
# 569
# {'mapreduce': 1, 'spark': 51, 'python': 145, 'r': 215, 'sql': 85, 'nosql': 21, 'sas': 15}
# HTTPError:
# HTTPError:
# 564
# {'mapreduce': 2, 'spark': 52, 'python': 146, 'r': 217, 'sql': 85, 'nosql': 22, 'sas': 16}
# HTTPError:
# 559
# {'mapreduce': 2, 'spark': 53, 'python': 148, 'r': 219, 'sql': 86, 'nosql': 22, 'sas': 16}
# HTTPError:
# 554
# {'mapreduce': 2, 'spark': 54, 'python': 150, 'r': 220, 'sql': 87, 'nosql': 22, 'sas': 16}
# URLError:
# 549
# {'mapreduce': 2, 'spark': 55, 'python': 152, 'r': 223, 'sql': 89, 'nosql': 22, 'sas': 17}
# 544
# {'mapreduce': 2, 'spark': 56, 'python': 154, 'r': 227, 'sql': 91, 'nosql': 22, 'sas': 17}
# 539
# {'mapreduce': 2, 'spark': 56, 'python': 157, 'r': 231, 'sql': 94, 'nosql': 22, 'sas': 17}
# HTTPError:
# URLError:
# 529
# {'mapreduce': 2, 'spark': 57, 'python': 158, 'r': 238, 'sql': 95, 'nosql': 22, 'sas': 17}
# HTTPError:
# 524
# {'mapreduce': 2, 'spark': 57, 'python': 161, 'r': 240, 'sql': 96, 'nosql': 22, 'sas': 17}
# HTTPError:
# 519
# {'mapreduce': 2, 'spark': 57, 'python': 161, 'r': 243, 'sql': 97, 'nosql': 22, 'sas': 17}
# 514
# {'mapreduce': 3, 'spark': 58, 'python': 164, 'r': 246, 'sql': 97, 'nosql': 23, 'sas': 18}
# HTTPError:
# 509
# {'mapreduce': 3, 'spark': 58, 'python': 165, 'r': 249, 'sql': 98, 'nosql': 23, 'sas': 18}
# 504
# {'mapreduce': 5, 'spark': 60, 'python': 169, 'r': 254, 'sql': 99, 'nosql': 24, 'sas': 18}
# URLError:
# HTTPError:
# 494
# {'mapreduce': 5, 'spark': 61, 'python': 173, 'r': 259, 'sql': 101, 'nosql': 25, 'sas': 18}
# 489
# {'mapreduce': 5, 'spark': 61, 'python': 175, 'r': 262, 'sql': 103, 'nosql': 25, 'sas': 18}
# HTTPError:
# HTTPError:
# 484
# {'mapreduce': 5, 'spark': 61, 'python': 176, 'r': 264, 'sql': 103, 'nosql': 25, 'sas': 18}
# 479
# {'mapreduce': 5, 'spark': 61, 'python': 177, 'r': 269, 'sql': 104, 'nosql': 26, 'sas': 19}
# 474
# {'mapreduce': 5, 'spark': 63, 'python': 179, 'r': 274, 'sql': 105, 'nosql': 26, 'sas': 19}
# HTTPError:
# HTTPError:
# URLError:
# 464
# {'mapreduce': 5, 'spark': 65, 'python': 182, 'r': 279, 'sql': 106, 'nosql': 27, 'sas': 19}
# 459
# {'mapreduce': 5, 'spark': 66, 'python': 183, 'r': 283, 'sql': 107, 'nosql': 27, 'sas': 19}
# HTTPError:
# HTTPError:
# 454
# {'mapreduce': 5, 'spark': 66, 'python': 183, 'r': 285, 'sql': 107, 'nosql': 27, 'sas': 19}
# HTTPError:
# HTTPError:
# HTTPError:
# HTTPError:
# HTTPError:
# 444
# {'mapreduce': 5, 'spark': 66, 'python': 184, 'r': 288, 'sql': 107, 'nosql': 27, 'sas': 19}
# HTTPError:
# HTTPError:
# 439
# {'mapreduce': 5, 'spark': 66, 'python': 186, 'r': 291, 'sql': 108, 'nosql': 27, 'sas': 19}
# HTTPError:
# HTTPError:
# 434
# {'mapreduce': 5, 'spark': 66, 'python': 188, 'r': 294, 'sql': 108, 'nosql': 28, 'sas': 19}
# HTTPError:
# 429
# {'mapreduce': 5, 'spark': 67, 'python': 189, 'r': 297, 'sql': 108, 'nosql': 28, 'sas': 19}
# HTTPError:
# 424
# {'mapreduce': 5, 'spark': 67, 'python': 189, 'r': 300, 'sql': 108, 'nosql': 28, 'sas': 19}
# 419
# {'mapreduce': 5, 'spark': 68, 'python': 190, 'r': 303, 'sql': 109, 'nosql': 28, 'sas': 19}
# 414
# {'mapreduce': 5, 'spark': 69, 'python': 190, 'r': 308, 'sql': 111, 'nosql': 28, 'sas': 19}
# URLError:
# HTTPError:
# HTTPError:
# 404
# {'mapreduce': 5, 'spark': 71, 'python': 191, 'r': 311, 'sql': 112, 'nosql': 28, 'sas': 19}
# 399
# {'mapreduce': 5, 'spark': 71, 'python': 192, 'r': 316, 'sql': 112, 'nosql': 28, 'sas': 19}
# HTTPError:
# 394
# {'mapreduce': 5, 'spark': 73, 'python': 195, 'r': 319, 'sql': 114, 'nosql': 29, 'sas': 19}
# HTTPError:
# HTTPError:
# 384
# {'mapreduce': 5, 'spark': 74, 'python': 196, 'r': 325, 'sql': 116, 'nosql': 29, 'sas': 19}
# HTTPError:
# 374
# {'mapreduce': 5, 'spark': 74, 'python': 196, 'r': 333, 'sql': 117, 'nosql': 31, 'sas': 19}
# 369
# {'mapreduce': 5, 'spark': 75, 'python': 200, 'r': 336, 'sql': 118, 'nosql': 33, 'sas': 19}
# HTTPError:
# 364
# {'mapreduce': 5, 'spark': 76, 'python': 202, 'r': 339, 'sql': 118, 'nosql': 33, 'sas': 19}
# 359
# {'mapreduce': 5, 'spark': 76, 'python': 202, 'r': 342, 'sql': 118, 'nosql': 33, 'sas': 19}
# 354
# {'mapreduce': 5, 'spark': 76, 'python': 204, 'r': 346, 'sql': 119, 'nosql': 33, 'sas': 19}
# HTTPError:
# 344
# {'mapreduce': 5, 'spark': 78, 'python': 209, 'r': 353, 'sql': 120, 'nosql': 33, 'sas': 19}
# HTTPError:
# 339
# {'mapreduce': 5, 'spark': 80, 'python': 210, 'r': 357, 'sql': 121, 'nosql': 33, 'sas': 19}
# HTTPError:
# HTTPError:
# HTTPError:
# 329
# {'mapreduce': 5, 'spark': 81, 'python': 211, 'r': 363, 'sql': 122, 'nosql': 33, 'sas': 19}
# 324
# {'mapreduce': 5, 'spark': 81, 'python': 211, 'r': 365, 'sql': 122, 'nosql': 33, 'sas': 19}
# HTTPError:
# 314
# {'mapreduce': 5, 'spark': 83, 'python': 214, 'r': 372, 'sql': 124, 'nosql': 33, 'sas': 19}
# HTTPError:
# 309
# {'mapreduce': 5, 'spark': 83, 'python': 214, 'r': 374, 'sql': 124, 'nosql': 33, 'sas': 19}
# HTTPError:
# 299
# {'mapreduce': 5, 'spark': 85, 'python': 216, 'r': 378, 'sql': 125, 'nosql': 34, 'sas': 19}
# HTTPError:
# HTTPError:
# HTTPError:
# 289
# {'mapreduce': 5, 'spark': 86, 'python': 219, 'r': 381, 'sql': 126, 'nosql': 34, 'sas': 19}
# HTTPError:
# 284
# {'mapreduce': 5, 'spark': 86, 'python': 219, 'r': 382, 'sql': 126, 'nosql': 34, 'sas': 19}
# HTTPError:
# HTTPError:
# HTTPError:
# 274
# {'mapreduce': 5, 'spark': 86, 'python': 219, 'r': 386, 'sql': 126, 'nosql': 34, 'sas': 19}
# 269
# {'mapreduce': 6, 'spark': 87, 'python': 221, 'r': 390, 'sql': 127, 'nosql': 35, 'sas': 20}
# HTTPError:
# HTTPError:
# HTTPError:
# 259
# {'mapreduce': 6, 'spark': 88, 'python': 223, 'r': 393, 'sql': 128, 'nosql': 35, 'sas': 21}
# 254
# {'mapreduce': 6, 'spark': 89, 'python': 226, 'r': 397, 'sql': 129, 'nosql': 36, 'sas': 21}
# 249
# {'mapreduce': 6, 'spark': 91, 'python': 227, 'r': 402, 'sql': 129, 'nosql': 37, 'sas': 21}
# HTTPError:
# 244
# {'mapreduce': 6, 'spark': 91, 'python': 228, 'r': 404, 'sql': 130, 'nosql': 37, 'sas': 21}
# HTTPError:
# 239
# {'mapreduce': 6, 'spark': 92, 'python': 231, 'r': 405, 'sql': 132, 'nosql': 37, 'sas': 21}
# HTTPError:
# 234
# {'mapreduce': 6, 'spark': 92, 'python': 233, 'r': 409, 'sql': 133, 'nosql': 37, 'sas': 21}
# HTTPError:
# 229
# {'mapreduce': 6, 'spark': 92, 'python': 236, 'r': 412, 'sql': 134, 'nosql': 37, 'sas': 21}
# URLError:
# 224
# {'mapreduce': 6, 'spark': 92, 'python': 237, 'r': 416, 'sql': 135, 'nosql': 37, 'sas': 22}
# 219
# {'mapreduce': 6, 'spark': 94, 'python': 240, 'r': 419, 'sql': 138, 'nosql': 39, 'sas': 22}
# HTTPError:
# HTTPError:
# HTTPError:
# 214
# {'mapreduce': 6, 'spark': 94, 'python': 240, 'r': 420, 'sql': 139, 'nosql': 39, 'sas': 22}
# HTTPError:
# 209
# {'mapreduce': 6, 'spark': 94, 'python': 241, 'r': 423, 'sql': 139, 'nosql': 39, 'sas': 22}
# HTTPError:
# 204
# {'mapreduce': 6, 'spark': 94, 'python': 243, 'r': 425, 'sql': 141, 'nosql': 41, 'sas': 22}
# HTTPError:
# HTTPError:
# HTTPError:
# 199
# {'mapreduce': 6, 'spark': 94, 'python': 243, 'r': 426, 'sql': 141, 'nosql': 41, 'sas': 22}
# HTTPError:
# 194
# {'mapreduce': 6, 'spark': 95, 'python': 244, 'r': 429, 'sql': 141, 'nosql': 41, 'sas': 22}
# 189
# {'mapreduce': 6, 'spark': 96, 'python': 245, 'r': 433, 'sql': 143, 'nosql': 42, 'sas': 23}
# HTTPError:
# HTTPError:
# HTTPError:
# 179
# {'mapreduce': 6, 'spark': 97, 'python': 247, 'r': 439, 'sql': 146, 'nosql': 43, 'sas': 23}
# HTTPError:
# HTTPError:
# 174
# {'mapreduce': 6, 'spark': 97, 'python': 248, 'r': 442, 'sql': 146, 'nosql': 43, 'sas': 23}
# HTTPError:
# HTTPError:
# 164
# {'mapreduce': 6, 'spark': 98, 'python': 250, 'r': 446, 'sql': 148, 'nosql': 43, 'sas': 23}
# 159
# {'mapreduce': 6, 'spark': 99, 'python': 251, 'r': 450, 'sql': 149, 'nosql': 43, 'sas': 23}
# HTTPError:
# HTTPError:
# HTTPError:
# HTTPError:
# 149
# {'mapreduce': 6, 'spark': 99, 'python': 251, 'r': 454, 'sql': 149, 'nosql': 43, 'sas': 23}
# 144
# {'mapreduce': 6, 'spark': 99, 'python': 252, 'r': 458, 'sql': 150, 'nosql': 43, 'sas': 23}
# 139
# {'mapreduce': 6, 'spark': 100, 'python': 253, 'r': 463, 'sql': 152, 'nosql': 44, 'sas': 23}
# URLError:
# HTTPError:
# HTTPError:
# HTTPError:
# HTTPError:
# HTTPError:
# 114
# {'mapreduce': 7, 'spark': 103, 'python': 261, 'r': 479, 'sql': 160, 'nosql': 45, 'sas': 24}
# 109
# {'mapreduce': 7, 'spark': 103, 'python': 262, 'r': 482, 'sql': 160, 'nosql': 45, 'sas': 24}
# 104
# {'mapreduce': 7, 'spark': 103, 'python': 263, 'r': 486, 'sql': 160, 'nosql': 45, 'sas': 24}
# URLError:
# HTTPError:
# HTTPError:
# HTTPError:
# 94
# {'mapreduce': 7, 'spark': 104, 'python': 266, 'r': 492, 'sql': 163, 'nosql': 45, 'sas': 25}
# HTTPError:
# HTTPError:
# HTTPError:
# HTTPError:
# HTTPError:
# HTTPError:
# HTTPError:
# 79
# {'mapreduce': 7, 'spark': 104, 'python': 269, 'r': 500, 'sql': 164, 'nosql': 47, 'sas': 25}
# HTTPError:
# HTTPError:
# 74
# {'mapreduce': 7, 'spark': 104, 'python': 269, 'r': 503, 'sql': 165, 'nosql': 48, 'sas': 25}
# HTTPError:
# HTTPError:
# 69
# {'mapreduce': 7, 'spark': 104, 'python': 269, 'r': 506, 'sql': 165, 'nosql': 48, 'sas': 25}
# HTTPError:
# HTTPError:
# 64
# {'mapreduce': 7, 'spark': 104, 'python': 269, 'r': 508, 'sql': 165, 'nosql': 48, 'sas': 25}
# HTTPError:
# HTTPError:
# HTTPError:
# HTTPError:
# 54
# {'mapreduce': 7, 'spark': 106, 'python': 271, 'r': 511, 'sql': 166, 'nosql': 49, 'sas': 25}
# HTTPError:
# HTTPError:
# HTTPError:
# HTTPError:
# 39
# {'mapreduce': 7, 'spark': 110, 'python': 278, 'r': 519, 'sql': 168, 'nosql': 50, 'sas': 25}
# HTTPError:
# HTTPError:
# HTTPError:
# HTTPError:
# 24
# {'mapreduce': 7, 'spark': 114, 'python': 285, 'r': 527, 'sql': 170, 'nosql': 51, 'sas': 25}
# HTTPError:
# 14
# {'mapreduce': 7, 'spark': 117, 'python': 291, 'r': 534, 'sql': 173, 'nosql': 51, 'sas': 26}
# HTTPError:
# HTTPError:
# HTTPError:
# 4
# {'mapreduce': 7, 'spark': 118, 'python': 292, 'r': 537, 'sql': 174, 'nosql': 51, 'sas': 26}
# URLError:

# %% [markdown]
# ### Visualize
# Present results in a bar graph.

# %%
pseries = pd.Series(skill_set)
pseries.sort_values(ascending=False)

pseries.plot(kind = 'bar')
## set the title to Score Comparison
plt.title('Data Science Skills')
## set the x label
plt.xlabel('Skills')
## set the y label
plt.ylabel('Count')
## show the plot
plt.show()

# %% [markdown]
# ### Remarks

# %% [markdown]
# Code is based on the [2015 CS109 solution](https://github.com/cs109/2015/blob/master/Lectures/02-DataScrapingQuizzes.ipynb).
# * some minor changes due to Python v2 vs v3 differences
# * the number of jobresults per page is varying.
# * quite a number of job links are duplicates. Might be due to advertisements.
# * skill in language R is given the above code hard to find. As a consequence the final R count is too high. A solution migt be the approach by  [Jesse Steinweg-Woods](https://jessesw.com/Data-Science-Skills/)
# * the searchCount is located on a different html location
# * the searchCount on the first page is not always reliable. Example of 18 August 2020: searchCount 7, but 10 job postings on page. Or searchCount 20 and 18 on page(s).
